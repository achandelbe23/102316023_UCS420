# %% [markdown]
# # Assignment 9

# %% [markdown]
# Q1. Write a unique paragraph (5-6 sentences) about your favorite topic (e.g., sports,
# technology, food, books, etc.).
# 1. Convert text to lowercase and remove punctuation.
# 2. Tokenize the text into words and sentences.
# 3. Remove stopwords (using NLTK's stopwords list).
# 4. Display word frequency distribuion (excluding stopwords).

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
import string
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist


# i
paragraph = """"Fernando Alonso is one of the most skilled drivers in Formula 1 history, known for his razor-sharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars. His signature overtaking maneuvers, especially under braking, have left countless rivals in disbelief, while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship.
Throughout his career, Alonso has demonstrated a unique blend of race intelligence, adaptability, and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch. Despite controversies surrounding his outspoken views and team choices, his talent behind the wheel isn't up for debate and continues to inspire a generation of young racers worldwide.
Fernando doesn't give up easily, won't back down from a challenge, and can't be written off — even at 40+. Behind him is not just experience, but lawrence stroll's support technology and excellent race engineering pushing him forward.

For the last Ques, I , Aayushman, need to add phrases like: don't, isn't, won't, can't,
state-of-the-art technology and cutting-edge.
The value of pi is 3.14159. My email is achandel_be23@thapaer.edu.
https://www.example.com. Call us at 123-456-7890 or +91 9988776655.
"""

print("Original Paragraph: ")
print(paragraph)
# i
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

cleaned_para = clean_text(paragraph)
print(f"Cleaned Text: \n{cleaned_para}")

# ii
sentences = sent_tokenize(paragraph)
words = word_tokenize(cleaned_para)

print(f"Number of sentences: {len(sentences)}")
print("Sentences:")
for i, sentence in enumerate(sentences, 1):
    print(f"{i}. {sentence}")

print(f"\nNumber of words: {len(words)}")
print(f"First 15 tokens: {words[:15]}")

# iii
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word not in stop_words]
print(f"Number of words after stopword removal: {len(filtered_words)}")


fdist = FreqDist(filtered_words)
print("Word Frequencies (Top 10):")
for word, frequency in fdist.most_common(10):
    print(f"{word}: {frequency}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chand\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chand\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\chand\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\chand\AppData\Roaming\nltk_data...
# Original Paragraph:
# "Fernando Alonso is one of the most skilled drivers in Formula 1 history, known for his razor-sharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars. His signature overtaking maneuvers, especially under braking, have left countless rivals in disbelief, while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship.
# Throughout his career, Alonso has demonstrated a unique blend of race intelligence, adaptability, and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch. Despite controversies surrounding his outspoken views and team choices, his talent behind the wheel isn't up for debate and continues to inspire a generation of young racers worldwide.
# Fernando doesn't give up easily, won't back down from a challenge, and can't be written off — even at 40+. Behind him is not just experience, but lawrence stroll's support technology and excellent race engineering pushing him forward.
#
# For the last Ques, I , Aayushman, need to add phrases like: don't, isn't, won't, can't,
# state-of-the-art technology and cutting-edge.
# The value of pi is 3.14159. My email is achandel_be23@thapaer.edu.
# https://www.example.com. Call us at 123-456-7890 or +91 9988776655.
#
# Cleaned Text:
# fernando alonso is one of the most skilled drivers in formula 1 history known for his razorsharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars his signature overtaking maneuvers especially under braking have left countless rivals in disbelief while his clutch performance while being defended by michael schumacher in 2005 helped renault clinch their first f1 world championship
# throughout his career alonso has demonstrated a unique blend of race intelligence adaptability and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch despite controversies surrounding his outspoken views and team choices his talent behind the wheel isnt up for debate and continues to inspire a generation of young racers worldwide
# fernando doesnt give up easily wont back down from a challenge and cant be written off — even at 40 behind him is not just experience but lawrence strolls support technology and excellent race engineering pushing him forward
#
# for the last ques i  aayushman need to add phrases like dont isnt wont cant
# stateoftheart technology and cuttingedge
# the value of pi is 314159 my email is achandelbe23thapaeredu
# httpswwwexamplecom call us at 1234567890 or 91 9988776655
#
# Number of sentences: 11
# Sentences:
# 1. "Fernando Alonso is one of the most skilled drivers in Formula 1 history, known for his razor-sharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars.
# 2. His signature overtaking maneuvers, especially under braking, have left countless rivals in disbelief, while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship.
# 3. Throughout his career, Alonso has demonstrated a unique blend of race intelligence, adaptability, and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch.
# 4. Despite controversies surrounding his outspoken views and team choices, his talent behind the wheel isn't up for debate and continues to inspire a generation of young racers worldwide.
# 5. Fernando doesn't give up easily, won't back down from a challenge, and can't be written off — even at 40+.
# 6. Behind him is not just experience, but lawrence stroll's support technology and excellent race engineering pushing him forward.
# 7. For the last Ques, I , Aayushman, need to add phrases like: don't, isn't, won't, can't,
# state-of-the-art technology and cutting-edge.
# 8. The value of pi is 3.14159.
# 9. My email is achandel_be23@thapaer.edu.
# 10. https://www.example.com.
# 11. Call us at 123-456-7890 or +91 9988776655.
#
# Number of words: 195
# First 15 tokens: ['fernando', 'alonso', 'is', 'one', 'of', 'the', 'most', 'skilled', 'drivers', 'in', 'formula', '1', 'history', 'known', 'for']
# Number of words after stopword removal: 125
# Word Frequencies (Top 10):
# fernando: 2
# alonso: 2
# performance: 2
# even: 2
# race: 2
# behind: 2
# isnt: 2
# wont: 2
# cant: 2
# technology: 2

# %% [markdown]
# Q2. Stemming and Lemmatization
# 1. Take the tokenized words from Question 1 (after stopword removal).
# 2. Apply stemming using NLTK's PorterStemmer and LancasterStemmer.
# 3. Apply Lemmatization using NLTK's WordNetLemmatizer.
# 4. Compare and display results of both techniques.

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, WordNetLemmatizer
import pandas as pd


porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

# i.
print("First few filtered words:", filtered_words[:10])

# ii.
porter_stemmed = [porter_stemmer.stem(word) for word in filtered_words]
lancaster_stemmed = [lancaster_stemmer.stem(word) for word in filtered_words]

# iii.
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_words]

# iv.
print("\n~~ Comparison ~~")
print(f"{'Original':<15} {'Porter':<15} {'Lancaster':<15} {'Lemmatized':<15}")
print("-" * 60)

for i in range(min(10, len(filtered_words))):  # Limit to first 10 words for simplicity
    print(f"{filtered_words[i]:<15} {porter_stemmed[i]:<15} {lancaster_stemmed[i]:<15} {lemmatized[i]:<15}")
# Out:
# First few filtered words: ['fernando', 'alonso', 'one', 'skilled', 'drivers', 'formula', '1', 'history', 'known', 'razorsharp']
#
# ~~ Comparison ~~
# Original        Porter          Lancaster       Lemmatized
# ------------------------------------------------------------
# fernando        fernando        fernando        fernando
# alonso          alonso          alonso          alonso
# one             one             on              one
# skilled         skill           skil            skilled
# drivers         driver          driv            driver
# formula         formula         formul          formula
# 1               1               1               1
# history         histori         hist            history
# known           known           known           known
# razorsharp      razorsharp      razorsharp      razorsharp

# %% [markdown]
# Q3. Regular Expressions and Text Splitting
# 1. Take their original text from Question 1.
# 2. Use regular expressions to:
#    - a. Extract all words with more than 5 letters.
#    - b. Extract all numbers (if any exist in their text).
#    - c. Extract all capitalized words.
# 3. Use text splitting techniques to:
#    - a. Split the text into words containing only alphabets (removing digits and special characters).
#     - b. Extract words starting with a vowel.

# %%
import re

# 1.
print(paragraph)

# 2.
long_words = re.findall(r'\b\w{6,}\b', paragraph)
print(f"Words with more than 5 letters: {long_words}")

numbers = re.findall(r'\d+', paragraph)
print(f"All numbers: {numbers}")

capitalized_words = re.findall(r'\b[A-Z][a-z]*\b', paragraph)
print(f"Capitalized words: {capitalized_words}")

# 3.
alpha_only = re.findall(r'\b[a-zA-Z]+\b', paragraph)
print(f"Words with only alphabets: {alpha_only}")

vowel_words = re.findall(r'\b[aeiouAEIOU]\w*\b', paragraph)
print(f"Words starting with a vowel: {vowel_words}")
# Out:
# "Fernando Alonso is one of the most skilled drivers in Formula 1 history, known for his razor-sharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars. His signature overtaking maneuvers, especially under braking, have left countless rivals in disbelief, while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship.
# Throughout his career, Alonso has demonstrated a unique blend of race intelligence, adaptability, and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch. Despite controversies surrounding his outspoken views and team choices, his talent behind the wheel isn't up for debate and continues to inspire a generation of young racers worldwide.
# Fernando doesn't give up easily, won't back down from a challenge, and can't be written off — even at 40+. Behind him is not just experience, but lawrence stroll's support technology and excellent race engineering pushing him forward.
#
# For the last Ques, I , Aayushman, need to add phrases like: don't, isn't, won't, can't,
# state-of-the-art technology and cutting-edge.
# The value of pi is 3.14159. My email is achandel_be23@thapaer.edu.
# https://www.example.com. Call us at 123-456-7890 or +91 9988776655.
#
# Words with more than 5 letters: ['Fernando', 'Alonso', 'skilled', 'drivers', 'Formula', 'history', 'racecraft', 'mesmerizing', 'ability', 'extract', 'performance', 'underperforming', 'signature', 'overtaking', 'maneuvers', 'especially', 'braking', 'countless', 'rivals', 'disbelief', 'clutch', 'performance', 'defended', 'Michael', 'Schumacher', 'helped', 'Renault', 'clinch', 'Championship', 'Throughout', 'career', 'Alonso', 'demonstrated', 'unique', 'intelligence', 'adaptability', 'technical', 'precision', 'driving', 'ruthlessly', 'effective', 'artistically', 'brilliant', 'Despite', 'controversies', 'surrounding', 'outspoken', 'choices', 'talent', 'behind', 'debate', 'continues', 'inspire', 'generation', 'racers', 'worldwide', 'Fernando', 'easily', 'challenge', 'written', 'Behind', 'experience', 'lawrence', 'stroll', 'support', 'technology', 'excellent', 'engineering', 'pushing', 'forward', 'Aayushman', 'phrases', 'technology', 'cutting', 'achandel_be23', 'thapaer', 'example', '9988776655']
# All numbers: ['1', '2005', '1', '40', '3', '14159', '23', '123', '456', '7890', '91', '9988776655']
# Capitalized words: ['Fernando', 'Alonso', 'Formula', 'His', 'Michael', 'Schumacher', 'Renault', 'World', 'Championship', 'Throughout', 'Alonso', 'Despite', 'Fernando', 'Behind', 'For', 'Ques', 'I', 'Aayushman', 'The', 'My', 'Call']
# Words with only alphabets: ['Fernando', 'Alonso', 'is', 'one', 'of', 'the', 'most', 'skilled', 'drivers', 'in', 'Formula', 'history', 'known', 'for', 'his', 'razor', 'sharp', 'racecraft', 'and', 'mesmerizing', 'ability', 'to', 'extract', 'performance', 'from', 'even', 'the', 'most', 'underperforming', 'cars', 'His', 'signature', 'overtaking', 'maneuvers', 'especially', 'under', 'braking', 'have', 'left', 'countless', 'rivals', 'in', 'disbelief', 'while', 'his', 'clutch', 'performance', 'while', 'being', 'defended', 'by', 'Michael', 'Schumacher', 'in', 'helped', 'Renault', 'clinch', 'their', 'first', 'World', 'Championship', 'Throughout', 'his', 'career', 'Alonso', 'has', 'demonstrated', 'a', 'unique', 'blend', 'of', 'race', 'intelligence', 'adaptability', 'and', 'technical', 'precision', 'that', 'makes', 'his', 'driving', 'style', 'both', 'ruthlessly', 'effective', 'and', 'artistically', 'brilliant', 'to', 'watch', 'Despite', 'controversies', 'surrounding', 'his', 'outspoken', 'views', 'and', 'team', 'choices', 'his', 'talent', 'behind', 'the', 'wheel', 'isn', 't', 'up', 'for', 'debate', 'and', 'continues', 'to', 'inspire', 'a', 'generation', 'of', 'young', 'racers', 'worldwide', 'Fernando', 'doesn', 't', 'give', 'up', 'easily', 'won', 't', 'back', 'down', 'from', 'a', 'challenge', 'and', 'can', 't', 'be', 'written', 'off', 'even', 'at', 'Behind', 'him', 'is', 'not', 'just', 'experience', 'but', 'lawrence', 'stroll', 's', 'support', 'technology', 'and', 'excellent', 'race', 'engineering', 'pushing', 'him', 'forward', 'For', 'the', 'last', 'Ques', 'I', 'Aayushman', 'need', 'to', 'add', 'phrases', 'like', 'don', 't', 'isn', 't', 'won', 't', 'can', 't', 'state', 'of', 'the', 'art', 'technology', 'and', 'cutting', 'edge', 'The', 'value', 'of', 'pi', 'is', 'My', 'email', 'is', 'thapaer', 'edu', 'https', 'www', 'example', 'com', 'Call', 'us', 'at', 'or']
# Words starting with a vowel: ['Alonso', 'is', 'one', 'of', 'in', 'and', 'ability', 'extract', 'even', 'underperforming', 'overtaking', 'especially', 'under', 'in', 'in', 'Alonso', 'a', 'unique', 'of', 'intelligence', 'adaptability', 'and', 'effective', 'and', 'artistically', 'outspoken', 'and', 'isn', 'up', 'and', 'inspire', 'a', 'of', 'up', 'easily', 'a', 'and', 'off', 'even', 'at', 'is', 'experience', 'and', 'excellent', 'engineering', 'I', 'Aayushman', 'add', 'isn', 'of', 'art', 'and', 'edge', 'of', 'is', 'email', 'is', 'achandel_be23', 'edu', 'example', 'us', 'at', 'or']

# %% [markdown]
# **Q4. Custom Tokenization & Regex-based Text Cleaning**
# 1. Take original text from Question 1.
# 2. Write a custom tokenization function that:
#     a. Removes punctuation and special symbols, but keeps contractions (e.g., "isn't" should not be split into "is" and "n't").
#     b. Handles hyphenated words as a single token (e.g., "state-of-the-art" remains a single token).
#     c. Tokenizes numbers separately but keeps decimal numbers intact (e.g., "3.14" should remain as is).
#
# 3. Use Regex Substitutions (re.sub) to:
#     a. Replace email addresses with '<EMAIL>' placeholder.
#     b. Replace URLs with '<URL>' placeholder.
#     c. Replace phone numbers (formats: 123-456-7890 or +91 9876543210) with '<PHONE>' placeholder.

# %%
import re

print("Original Paragraph:")
print(paragraph)
print("-" * 40)


def custom_tokenize(text):
    
    text = re.sub(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b', '<EMAIL>', text)
    text = re.sub(r'https?://[^\s]+', '<URL>', text)
    text = re.sub(r'\b\d{3}-\d{3}-\d{4}\b', '<PHONE>', text)
    text = re.sub(r'\+\d{1,3}\s\d{10}\b', '<PHONE>', text)

    text = re.sub(r"(\w+)\'(\w+)", r"\1_APOS_\2", text)

    hyphens = re.findall(r'\b[\w]+-[\w-]+\b', text)
    for i, word in enumerate(hyphens):
        text = text.replace(word, f"_HYPHEN_{i}_")

    decimals = re.findall(r'\b\d+\.\d+\b', text)
    for i, num in enumerate(decimals):
        text = text.replace(num, f"_DECIMAL_{i}_")
    text = re.sub(r'[^\w\s<>]', ' ', text)

    tokens = text.split()
    tokens = [t.replace('_APOS_', "'") for t in tokens]
    for i, word in enumerate(hyphens):
        tokens = [word if t == f"_HYPHEN_{i}_" else t for t in tokens]

    for i, num in enumerate(decimals):
        tokens = [num if t == f"_DECIMAL_{i}_" else t for t in tokens]
    return tokens, text

tokens, cleaned_text = custom_tokenize(paragraph)

print("Cleaned text with placeholders:")
print(cleaned_text)
print("Tokens:")
print(tokens)


print("\n")
print("Contractions:", [t for t in tokens if "'" in t])
print("Hyphenated words:", [t for t in tokens if "-" in t])
print("Decimals:", [t for t in tokens if re.match(r'\d+\.\d+', t)])
print("Placeholders:", [t for t in tokens if t in ['<EMAIL>', '<URL>', '<PHONE>']])
# Out:
# Original Paragraph:
# "Fernando Alonso is one of the most skilled drivers in Formula 1 history, known for his razor-sharp racecraft and mesmerizing ability to extract performance from even the most underperforming cars. His signature overtaking maneuvers, especially under braking, have left countless rivals in disbelief, while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship.
# Throughout his career, Alonso has demonstrated a unique blend of race intelligence, adaptability, and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch. Despite controversies surrounding his outspoken views and team choices, his talent behind the wheel isn't up for debate and continues to inspire a generation of young racers worldwide.
# Fernando doesn't give up easily, won't back down from a challenge, and can't be written off — even at 40+. Behind him is not just experience, but lawrence stroll's support technology and excellent race engineering pushing him forward.
#
# For the last Ques, I , Aayushman, need to add phrases like: don't, isn't, won't, can't,
# state-of-the-art technology and cutting-edge.
# The value of pi is 3.14159. My email is achandel_be23@thapaer.edu.
# https://www.example.com. Call us at 123-456-7890 or +91 9988776655.
#
# ----------------------------------------
# Cleaned text with placeholders:
#  Fernando Alonso is one of the most skilled drivers in Formula 1 history  known for his _HYPHEN_0_ racecraft and mesmerizing ability to extract performance from even the most underperforming cars  His signature overtaking maneuvers  especially under braking  have left countless rivals in disbelief  while his clutch performance while being defended by Michael Schumacher in 2005 helped Renault clinch their first F1 World Championship
# Throughout his career  Alonso has demonstrated a unique blend of race intelligence  adaptability  and technical precision that makes his driving style both ruthlessly effective and artistically brilliant to watch  Despite controversies surrounding his outspoken views and team choices  his talent behind the wheel isn_APOS_t up for debate and continues to inspire a generation of young racers worldwide
# Fernando doesn_APOS_t give up easily  won_APOS_t back down from a challenge  and can_APOS_t be written off   even at 40   Behind him is not just experience  but lawrence stroll_APOS_s support technology and excellent race engineering pushing him forward
#
# For the last Ques  I   Aayushman  need to add phrases like  don_APOS_t  isn_APOS_t  won_APOS_t  can_APOS_t
# _HYPHEN_1_ technology and _HYPHEN_2_
# The value of pi is _DECIMAL_0_  My email is <EMAIL>
# <URL> Call us at <PHONE> or <PHONE>
#
# Tokens:
# ['Fernando', 'Alonso', 'is', 'one', 'of', 'the', 'most', 'skilled', 'drivers', 'in', 'Formula', '1', 'history', 'known', 'for', 'his', 'razor-sharp', 'racecraft', 'and', 'mesmerizing', 'ability', 'to', 'extract', 'performance', 'from', 'even', 'the', 'most', 'underperforming', 'cars', 'His', 'signature', 'overtaking', 'maneuvers', 'especially', 'under', 'braking', 'have', 'left', 'countless', 'rivals', 'in', 'disbelief', 'while', 'his', 'clutch', 'performance', 'while', 'being', 'defended', 'by', 'Michael', 'Schumacher', 'in', '2005', 'helped', 'Renault', 'clinch', 'their', 'first', 'F1', 'World', 'Championship', 'Throughout', 'his', 'career', 'Alonso', 'has', 'demonstrated', 'a', 'unique', 'blend', 'of', 'race', 'intelligence', 'adaptability', 'and', 'technical', 'precision', 'that', 'makes', 'his', 'driving', 'style', 'both', 'ruthlessly', 'effective', 'and', 'artistically', 'brilliant', 'to', 'watch', 'Despite', 'controversies', 'surrounding', 'his', 'outspoken', 'views', 'and', 'team', 'choices', 'his', 'talent', 'behind', 'the', 'wheel', "isn't", 'up', 'for', 'debate', 'and', 'continues', 'to', 'inspire', 'a', 'generation', 'of', 'young', 'racers', 'worldwide', 'Fernando', "doesn't", 'give', 'up', 'easily', "won't", 'back', 'down', 'from', 'a', 'challenge', 'and', "can't", 'be', 'written', 'off', 'even', 'at', '40', 'Behind', 'him', 'is', 'not', 'just', 'experience', 'but', 'lawrence', "stroll's", 'support', 'technology', 'and', 'excellent', 'race', 'engineering', 'pushing', 'him', 'forward', 'For', 'the', 'last', 'Ques', 'I', 'Aayushman', 'need', 'to', 'add', 'phrases', 'like', "don't", "isn't", "won't", "can't", 'state-of-the-art', 'technology', 'and', 'cutting-edge', 'The', 'value', 'of', 'pi', 'is', '3.14159', 'My', 'email', 'is', '<EMAIL>', '<URL>', 'Call', 'us', 'at', '<PHONE>', 'or', '<PHONE>']
#
#
# Contractions: ["isn't", "doesn't", "won't", "can't", "stroll's", "don't", "isn't", "won't", "can't"]
# Hyphenated words: ['razor-sharp', 'state-of-the-art', 'cutting-edge']
# Decimals: ['3.14159']
# Placeholders: ['<EMAIL>', '<URL>', '<PHONE>', '<PHONE>']
